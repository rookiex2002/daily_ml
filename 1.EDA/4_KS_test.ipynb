# %% [markdown]
# # K-S Test

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
# generate a gaussian r.v
x=stats.norm.rvs(size=1000)
sns.set_style('whitegrid')
sns.kdeplot(np.array(x),bw=0.5)
plt.show()
# Out:
# /tmp/ipykernel_708/1594888227.py:4: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   sns.kdeplot(np.array(x),bw=0.5)

# %%
x=np.random.normal(loc=0,scale=1,size=1000)
sns.set_style('whitegrid')
sns.kdeplot(np.array(x),bw=0.5)
plt.show()
# Out:
# /tmp/ipykernel_708/1261264421.py:3: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   sns.kdeplot(np.array(x),bw=0.5)

# %%
stats.kstest(x,'norm')
# Out:
# KstestResult(statistic=np.float64(0.02525787613569369), pvalue=np.float64(0.5377569004453709), statistic_location=np.float64(-0.6226960974562634), statistic_sign=np.int8(1))

# %%
# Y ~ Continious Uniform Distribution (0,1)
y=np.random.uniform(0,1,1000)
sns.kdeplot(np.array(y),bw=0.5)
plt.show()
# Out:
# /tmp/ipykernel_708/2144520485.py:3: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   sns.kdeplot(np.array(y),bw=0.5)

# %%
stats.kstest(y,'norm')
# Out:
# KstestResult(statistic=np.float64(0.5004989964871743), pvalue=np.float64(3.4084119430483454e-232), statistic_location=np.float64(0.0012507990298380456), statistic_sign=np.int8(-1))
